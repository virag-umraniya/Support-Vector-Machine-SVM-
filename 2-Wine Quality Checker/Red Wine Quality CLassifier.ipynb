# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Collect or load dataset

# %%
df = pd.read_csv('winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ## 2. Basic Check

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ## 3. EDA

# %% [markdown]
# ### i. Univariate Analysis

# %%
for col in df:
    plt.figure(figsize=(8,4))
    sns.histplot(x=col, data=df, kde=True)

# %% [markdown]
# ### ii. Bivariate Analysis

# %%
for col in df:
    plt.figure(figsize=(8,4))
    sns.countplot(x=col, hue=df['quality'], data=df)

# %% [markdown]
# ### iii. Multivariate Analysis

# %%
sns.pairplot(df)

# %% [markdown]
# ## 4. Data Preprocessing

# %% [markdown]
# ### i. Checking for NaN/Outliers

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# for col in df:
#     plt.figure(figsize=(8,4))
#     sns.boxplot(x=col, data=df)

# %%
for col in df.drop('quality', axis=1):
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3-q1
    lb = q1 - 1.5 * iqr
    ub = q3 + 1.5 * iqr
    median = df[col].median()
    print(f'{col} q1:', q1)
    print(f'{col} q3:', q3)
    print(f'{col} iq1:', iqr)
    print(f'{col} lb:', lb)
    print(f'{col} ub:', ub)
    print(f'{col} median:', median)
    print('----------------------------------------------')
# Out:
# fixed acidity q1: 7.1
# fixed acidity q3: 9.2
# fixed acidity iq1: 2.0999999999999996
# fixed acidity lb: 3.95
# fixed acidity ub: 12.349999999999998
# fixed acidity median: 7.9
# ----------------------------------------------
# volatile acidity q1: 0.39
# volatile acidity q3: 0.64
# volatile acidity iq1: 0.25
# volatile acidity lb: 0.015000000000000013
# volatile acidity ub: 1.0150000000000001
# volatile acidity median: 0.52
# ----------------------------------------------
# citric acid q1: 0.09
# citric acid q3: 0.42
# citric acid iq1: 0.32999999999999996
# citric acid lb: -0.4049999999999999
# citric acid ub: 0.9149999999999999
# citric acid median: 0.26
# ----------------------------------------------
# residual sugar q1: 1.9
# residual sugar q3: 2.6
# residual sugar iq1: 0.7000000000000002
# residual sugar lb: 0.8499999999999996
# residual sugar ub: 3.6500000000000004
# residual sugar median: 2.2
# ----------------------------------------------
# chlorides q1: 0.07
# ...

# %%
df.loc[(df['fixed acidity'] > 12.22), 'fixed acidity'] = 7.9

# %%
df.loc[(df['volatile acidity'] > 1.02), 'volatile acidity'] = 0.52

# %%
df.loc[(df['citric acid'] > 0.91), 'citric acid'] = 0.26

# %%
df.loc[(df['residual sugar'] > 3.65), 'citric acid'] = 2.2

# %%
df.loc[(df['chlorides'] < 0.04) | (df['chlorides'] > 0.12), 'chlorides'] = 0.079

# %%
df.loc[(df['free sulfur dioxide'] > 42), 'free sulfur dioxide'] = 14

# %%
df.loc[(df['total sulfur dioxide'] > 122), 'total sulfur dioxide'] = 38

# %%
df.loc[(df['density'] < 0.99) | (df['density'] > 1), 'density'] = 0.99675

# %%
df.loc[(df['pH'] < 2.925) | (df['pH'] > 3.6849999999999996), 'pH'] = 3.31

# %%
df.loc[(df['sulphates'] > 0.99), 'sulphates'] = 0.62

# %%
df.loc[(df['alcohol'] > 13.5), 'alcohol'] = 10.2

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
X = df.drop('quality', axis=1)
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y = df[['quality']]
y
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           5
# ...       ...
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#
# [1599 rows x 1 columns]

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# df_scaled = scaler.fit_transform(X)
# df_scaled

# %%
# df_scaled = pd.DataFrame(df_scaled, columns=X.columns)
# df_scaled

# %%
# df_scaled = pd.concat([df_scaled, y.reset_index(drop=True)], axis=1)
# df_scaled

# %% [markdown]
# ## 5. Split the data

# %%
# Create Classification version of target variable
df['goodquality'] = [1 if x >= 7 else 0 for x in df['quality']]# Separate feature variables and target variable
X = df.drop(['quality','goodquality'], axis = 1)
Y = df[['goodquality']]

# %%
df.drop('quality', axis=1, inplace=True)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
X = df.drop('goodquality', axis=1)
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y = df[['goodquality']]
y
# Out:
#       goodquality
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 1594            0
# 1595            0
# 1596            0
# 1597            0
# 1598            0
#
# [1599 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ## 6. Fit the data to the model

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
from sklearn.metrics import classification_report

# Predict on training and test set
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Classification report on training data
print("=== Classification Report on Training Data ===")
print(classification_report(y_train, y_train_pred))

# Classification report on test data
print("=== Classification Report on Test Data ===")
print(classification_report(y_test, y_test_pred))
# Out:
# === Classification Report on Training Data ===
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      1094
#            1       0.00      0.00      0.00       185
#
#     accuracy                           0.86      1279
#    macro avg       0.43      0.50      0.46      1279
# weighted avg       0.73      0.86      0.79      1279
#
# === Classification Report on Test Data ===
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95       288
#            1       0.00      0.00      0.00        32
#
#     accuracy                           0.90       320
#    macro avg       0.45      0.50      0.47       320
# weighted avg       0.81      0.90      0.85       320
